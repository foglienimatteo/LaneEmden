# %%
import numpy as np
from matplotlib import pyplot as plt
from astropy.table import Table
import scipy.constants as cnst
import scipy.optimize as opt
import emcee
import corner

import matplotlib as mpl
mpl.rcParams['axes.titlesize'] = 16
mpl.rcParams['axes.labelsize'] = 14
mpl.rcParams['legend.fontsize'] = 12
mpl.rcParams['xtick.labelsize'] = 12
mpl.rcParams['ytick.labelsize'] = 12
#mpl.rcParams['axes.spines.right'] = False
#mpl.rcParams['axes.spines.top'] = False

# %% [markdown]
# $$
# \frac{1}{\xi^2}\frac{d}{d\xi}\left(\xi^2 \, \frac{d\theta}{d\xi}\right) = -\theta^n\,, \quad
# \mathrm{with} \;\; \theta(0)=1, \; \frac{d\theta}{d\xi}(0)=0
# $$

# %% [markdown]
# $$
# \begin{cases}
# \displaystyle \frac{d\theta}{d\xi}=\omega \\[12pt]
# \displaystyle \frac{d}{d\xi}\left(\xi^2 \omega\right)=-\xi^2 \, \theta^n
# \quad \Rightarrow \quad \frac{d \omega}{d\xi} = -\theta^n - 2 \frac{\omega}{\xi}
# \end{cases}
# $$

# %% [markdown]
# $$
# \frac{d}{d\xi} \left(\begin{matrix}
# \theta \\
# \omega
# \end{matrix}\right) =
# \left(\begin{matrix}
# \omega \\
# \displaystyle -\theta^n  - 2 \frac{\omega}{\xi}
# \end{matrix}\right)
# $$

# %% [markdown]
# $$
# g(\xi) := \frac{\rho}{\rho_c} = \theta^n(\xi) \, , \qquad
# f(\xi) := -\xi^2\frac{d\theta}{d\xi}(\xi)
# $$

# %% [markdown]
# $$
# h(\xi) := 3 \, \frac{f(\xi)}{\xi^3} \qquad
# \alpha(\xi) := \frac{1}{n+1}\left(\frac{4\pi}{f^2(\xi)}\right)^{1/3}
# $$

# %%
INDEX = 2.5
NOMI = np.array(["indice", "csi", "theta", "theta_p", "g_csi", "f_csi", "h_csi", "alpha_csi"])
table = Table.read(f'build/Lane-Emden_Eulero_n={INDEX}.dat', names = NOMI,  format="ascii")
table
# Out:
# <Table length=11990>
# indice   csi    theta     theta_p    g_csi      f_csi      h_csi   alpha_csi
# int64  float64 float64    float64   float64    float64    float64   float64
# ------ ------- -------- ----------- -------- ----------- --------- ---------
#      0    0.01      1.0         0.0      1.0        -0.0       0.0       inf
#      1   0.011      1.0      -0.001      1.0    1.21e-07 -0.272727   27152.6
#      2   0.012 0.999999 -0.00181818 0.999998 2.61818e-07 -0.454545   16230.6
#      3   0.013 0.999997 -0.00251515 0.999993  4.2506e-07 -0.580419   11749.9
#      4   0.014 0.999995  -0.0031282 0.999987 6.13126e-07 -0.670328   9203.83
#      5   0.015 0.999992  -0.0036813 0.999979 8.28292e-07 -0.736259   7531.47
#      6   0.016 0.999988 -0.00419044  0.99997 1.07275e-06 -0.785707   6338.73
#      7   0.017 0.999984  -0.0046666 0.999959 1.34865e-06 -0.823518   5441.72
#      8   0.018 0.999979 -0.00511755 0.999948 1.65809e-06 -0.852925   4741.66
#      9   0.019 0.999974 -0.00554888 0.999935 2.00315e-06 -0.876139   4180.17
#    ...     ...      ...         ...      ...         ...       ...       ...
#  11980   11.99      nan         nan      nan         nan       nan       nan
#  11981  11.991      nan         nan      nan         nan       nan       nan
#  11982  11.992      nan         nan      nan         nan       nan       nan
#  11983  11.993      nan         nan      nan         nan       nan       nan
#  11984  11.994      nan         nan      nan         nan       nan       nan
#  11985  11.995      nan         nan      nan         nan       nan       nan
#  11986  11.996      nan         nan      nan         nan       nan       nan
#  11987  11.997      nan         nan      nan         nan       nan       nan
#  11988  11.998      nan         nan      nan         nan       nan       nan
#  11989  11.999      nan         nan      nan         nan       nan       nan

# %%
ORDINE = {nome: i for i,nome in enumerate(NOMI)}
data = np.array( [ table[nome] for nome in NOMI  ] ).T

# %%
indici = data[:, ORDINE["indice"] ]
csis = data[:, ORDINE["csi"] ]
thetas = data[:, ORDINE["theta"] ]
thetas_p = data[:, ORDINE["theta_p"] ]
gcsis = data[:, ORDINE["g_csi"] ]
fcsis = data[:, ORDINE["f_csi"] ]
hcsis = data[:, ORDINE["h_csi"] ]
alphacsis = data[:, ORDINE["alpha_csi"] ]

# %%
REMOVE = 40
SIZE_ticks = 15
SIZE_labels = 20

fig, axs = plt.subplots(3, 2, figsize=(16, 20), tight_layout=True)
axs = axs.reshape(-1)

v_data = [thetas[REMOVE:], thetas_p[REMOVE:], gcsis[REMOVE:], 
          fcsis[REMOVE:], hcsis[REMOVE:], alphacsis[REMOVE:]]
v_ynames = [r'$\theta(\xi)$', r'$\frac{d\theta}{d\xi}(\xi)$', 
            r'$g(\xi)$', r'$f(\xi)$', r'$h(\xi)$', r'$\alpha(\xi)$']

for i in range(len(v_data)):
    ax = axs[i]
    ax.plot(csis[REMOVE:], v_data[i], '-', lw=3)
    ax.grid()
    #plt.xticks(np.arange(14,20,1), size=SIZE_2)
    #plt.yticks(np.arange(0,10,2), size=SIZE_2)
    ax.tick_params(axis='x', size=SIZE_ticks)
    ax.tick_params(axis='y', size=SIZE_ticks)
    ax.set_xlabel(r'$\xi$', size=SIZE_labels)
    ax.set_ylabel(v_ynames[i], size=SIZE_labels);

# %%
rho_norm = thetas**INDEX
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in power
#   """Entry point for launching an IPython kernel.

# %%
SIZE_ticks = 15
SIZE_labels = 20
Rows, Cols = 1, 2

fig = plt.figure(figsize = (16, 8))

plt.subplot(Rows, Cols, 1)
fig.subplots_adjust(wspace = 0.5, hspace = 0.2)
plt.plot(csis, rho_norm, '-', lw=3)
plt.grid()
#plt.xticks(np.arange(14,20,1), size=SIZE_2)
#plt.yticks(np.arange(0,10,2), size=SIZE_2)
plt.xticks(size=SIZE_ticks)
plt.yticks(size=SIZE_ticks)
plt.xlabel(r'$\xi$', size=SIZE_labels)
plt.ylabel(r'$\rho(\xi)/\rho_c$', size=SIZE_labels);



plt.subplot(Rows, Cols, 2)
fig.subplots_adjust(wspace = 0.2, hspace = 0.2)
firsts_N = 3
plt.plot(csis[firsts_N:], rho_norm[firsts_N:], '-', lw=3)
plt.grid()
#plt.xticks(np.arange(14,20,1))
#plt.yticks(np.arange(0,10,2))
plt.xticks(size=SIZE_ticks)
plt.yticks(size=SIZE_ticks)
plt.xlabel(r'$\xi$', size=SIZE_labels)
plt.ylabel(r'$\rho(\xi)/\rho_c$', size=SIZE_labels)
plt.xscale("log")
plt.yscale("log")

# %%
pressures_0 = np.array([f**2.0*g/4/np.pi for f,g in zip(fcsis, gcsis)])
volumes_0 = np.array([(csi/f)**3.0 for csi,f in zip(csis, fcsis)])
pressures_0, volumes_0
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in double_scalars
# (array([0.00000000e+00, 1.16509376e-15, 5.45491854e-15, ...,
#                    nan,            nan,            nan]),
#  array([          -inf, 7.51314801e+14, 9.62820293e+13, ...,
#                    nan,            nan,            nan]))

# %%
SIZE_ticks = 15
SIZE_labels = 15

fig, ax = plt.subplots(1, 1, figsize=(10, 6))
ax.plot(volumes_0, pressures_0, '-', lw=2)
ax.grid()
#plt.xticks(np.arange(14,20,1), size=SIZE_2)
#plt.yticks(np.arange(0,10,2), size=SIZE_2)
ax.tick_params(axis='x', size=SIZE_ticks)
ax.tick_params(axis='y', size=SIZE_ticks)
ax.set_xlabel(r'$(R_0/R_s)^3$', size=SIZE_labels)
ax.set_ylabel(r'$p_0/p_s$', size=SIZE_labels)
#ax.set_xlim(0., 1);
#ax.set_ylim(0., 1)
#plt.xscale("log")
#plt.yscale("log");
# Out:
# Text(0, 0.5, '$p_0/p_s$')

# %%
max(pressures_0), np.argmax(pressures_0), pressures_0[np.argmax(pressures_0)]
# Out:
# (0.025579612996806445, 5344, nan)

# %%
volumes_0[np.argmax(pressures_0)], volumes_0[np.argmax(pressures_0)]**0.333333
# Out:
# (14.686078193802429, 2.448884052866171)

# %%
np.where(volumes_0>10)[0][-1]
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in greater
#   """Entry point for launching an IPython kernel.
# 5344

# %%
ind_end = np.where(abs(volumes_0-0.6) < 0.01)[0][1]
ind_beg = np.where(volumes_0>10)[0][-1]
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in less
#   """Entry point for launching an IPython kernel.
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-13-a4d3d11e1c0e> in <module>
# ----> 1 ind_end = np.where(abs(volumes_0-0.6) < 0.01)[0][1]
#       2 ind_beg = np.where(volumes_0>10)[0][-1]
#
# IndexError: index 1 is out of bounds for axis 0 with size 0

# %%
plt.plot(volumes_0[ind_beg:ind_end], pressures_0[ind_beg:ind_end])

# %%
initial_value = 0.6
ending_value = 10
def func(x, a, b, c, d, e, f):
    #return a + d/x**3.0
    return a + b/x + c/x**2.0 + d/x**3.0+ e/x**4.0

# %%
ind_end = np.where(abs(volumes_0-initial_value) < 0.01)[0][1]
ind_beg = np.where(volumes_0>ending_value)[0][-1]
xdata = volumes_0[ind_beg:ind_end]
ydata = pressures_0[ind_beg:ind_end]
popt, pcov = opt.curve_fit(func, xdata, ydata)
popt

# %%
SIZE_ticks = 15
SIZE_labels = 15

fig, ax = plt.subplots(1, 1, figsize=(10, 6))
ax.plot(xdata, ydata, 'b-', lw=2, label="datas")
ax.plot(xdata, func(xdata, *popt), 'r--', lw=2, label="best fit")
ax.grid()
#plt.xticks(np.arange(14,20,1), size=SIZE_2)
#plt.yticks(np.arange(0,10,2), size=SIZE_2)
ax.tick_params(axis='x', size=SIZE_ticks)
ax.tick_params(axis='y', size=SIZE_ticks)
ax.set_xlabel(r'$(R_0/R_s)^3$', size=SIZE_labels)
ax.set_ylabel(r'$p_0/p_s$', size=SIZE_labels)
ax.set_xlim(initial_value, ending_value);
ax.legend();
#ax.set_ylim(0., 1)
#plt.xscale("log")
#plt.yscale("log");
